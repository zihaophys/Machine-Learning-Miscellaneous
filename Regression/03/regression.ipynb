# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pumpkins = pd.read_csv('../02/US-pumpkins.csv')

pumpkins.head()
# Out:
#    City Name Type       Package      Variety Sub Variety  Grade     Date  \
# 0  BALTIMORE  NaN  24 inch bins          NaN         NaN    NaN  4/29/17
# 1  BALTIMORE  NaN  24 inch bins          NaN         NaN    NaN   5/6/17
# 2  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN    NaN  9/24/16
# 3  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN    NaN  9/24/16
# 4  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN    NaN  11/5/16
#
#    Low Price  High Price  Mostly Low  ...  Unit of Sale Quality Condition  \
# 0      270.0       280.0       270.0  ...           NaN     NaN       NaN
# 1      270.0       280.0       270.0  ...           NaN     NaN       NaN
# 2      160.0       160.0       160.0  ...           NaN     NaN       NaN
# 3      160.0       160.0       160.0  ...           NaN     NaN       NaN
# 4       90.0       100.0        90.0  ...           NaN     NaN       NaN
#
#   Appearance Storage  Crop Repack  Trans Mode  Unnamed: 24  Unnamed: 25
# 0        NaN     NaN   NaN      E         NaN          NaN          NaN
# 1        NaN     NaN   NaN      E         NaN          NaN          NaN
# 2        NaN     NaN   NaN      N         NaN          NaN          NaN
# 3        NaN     NaN   NaN      N         NaN          NaN          NaN
# 4        NaN     NaN   NaN      N         NaN          NaN          NaN
#
# [5 rows x 26 columns]

# %%
pumpkins = pumpkins[pumpkins['Package'].str.contains('bushel', case=True, regex=True)]

new_columns = ['Package', 'Variety', 'City Name', 'Month', 'Low Price', 'High Price', 'Date', 'City Num', 'Variety Num']


pumpkins = pumpkins.drop([c for c in pumpkins.columns if c not in new_columns], axis=1)

price = (pumpkins['Low Price'] + pumpkins['High Price']) / 2

month = pd.DatetimeIndex(pumpkins['Date']).month


new_pumpkins = pd.DataFrame({'Month': month, 'Variety': pumpkins['Variety'], 'City': pumpkins['City Name'], 'Package': pumpkins['Package'], 'Low Price': pumpkins['Low Price'],'High Price': pumpkins['High Price'], 'Price': price})

new_pumpkins.loc[new_pumpkins['Package'].str.contains('1 1/9'), 'Price'] = price/1.1

new_pumpkins.loc[new_pumpkins['Package'].str.contains('1/2'), 'Price'] = price*2

new_pumpkins.head()
# Out:
#     Month   Variety       City               Package  Low Price  High Price  \
# 70      9  PIE TYPE  BALTIMORE  1 1/9 bushel cartons       15.0        15.0
# 71      9  PIE TYPE  BALTIMORE  1 1/9 bushel cartons       18.0        18.0
# 72     10  PIE TYPE  BALTIMORE  1 1/9 bushel cartons       18.0        18.0
# 73     10  PIE TYPE  BALTIMORE  1 1/9 bushel cartons       17.0        17.0
# 74     10  PIE TYPE  BALTIMORE  1 1/9 bushel cartons       15.0        15.0
#
#         Price
# 70  13.636364
# 71  16.363636
# 72  16.363636
# 73  15.454545
# 74  13.636364

# %%
new_pumpkins.describe()
# Out:
#             Month   Low Price  High Price       Price
# count  415.000000  415.000000  415.000000  415.000000
# mean     9.838554   18.007831   18.989759   27.707010
# std      0.748885    5.273335    5.694920    9.815351
# min      8.000000   10.750000   12.000000   10.909091
# 25%      9.000000   15.000000   17.000000   16.363636
# 50%     10.000000   17.000000   18.000000   30.000000
# 75%     10.000000   18.000000   19.000000   35.000000
# max     12.000000   48.000000   55.000000   51.500000

# %%
from sklearn.preprocessing import LabelEncoder

# %%
new_pumpkins
# Out:
#       Month    Variety       City               Package  Low Price  \
# 70        9   PIE TYPE  BALTIMORE  1 1/9 bushel cartons      15.00
# 71        9   PIE TYPE  BALTIMORE  1 1/9 bushel cartons      18.00
# 72       10   PIE TYPE  BALTIMORE  1 1/9 bushel cartons      18.00
# 73       10   PIE TYPE  BALTIMORE  1 1/9 bushel cartons      17.00
# 74       10   PIE TYPE  BALTIMORE  1 1/9 bushel cartons      15.00
# ...     ...        ...        ...                   ...        ...
# 1738      9  MINIATURE  ST. LOUIS    1/2 bushel cartons      15.00
# 1739      9  MINIATURE  ST. LOUIS    1/2 bushel cartons      13.75
# 1740      9  MINIATURE  ST. LOUIS    1/2 bushel cartons      10.75
# 1741      9  MINIATURE  ST. LOUIS    1/2 bushel cartons      12.00
# 1742      9  MINIATURE  ST. LOUIS    1/2 bushel cartons      12.00
#
#       High Price      Price
# 70          15.0  13.636364
# 71          18.0  16.363636
# 72          18.0  16.363636
# 73          17.0  15.454545
# 74          15.0  13.636364
# ...          ...        ...
# 1738        15.0  30.000000
# 1739        15.0  28.750000
# 1740        15.0  25.750000
# 1741        12.0  24.000000
# 1742        12.0  24.000000
#
# [415 rows x 7 columns]

# %%
new_pumpkins.iloc[:, 0:-1] = new_pumpkins.iloc[:, 0:-1].apply(LabelEncoder().fit_transform)
new_pumpkins
# Out:
#       Month  Variety  City  Package  Low Price  High Price      Price
# 70        1        3     1        0          5           3  13.636364
# 71        1        3     1        0         10           7  16.363636
# 72        2        3     1        0         10           7  16.363636
# 73        2        3     1        0          9           6  15.454545
# 74        2        3     1        0          5           3  13.636364
# ...     ...      ...   ...      ...        ...         ...        ...
# 1738      1        1     9        2          5           3  30.000000
# 1739      1        1     9        2          3           3  28.750000
# 1740      1        1     9        2          0           3  25.750000
# 1741      1        1     9        2          1           0  24.000000
# 1742      1        1     9        2          1           0  24.000000
#
# [415 rows x 7 columns]

# %%
new_pumpkins['City'].corr(new_pumpkins['Price'])
# Out:
# 0.3236397181608923

# %%
new_pumpkins.isnull().sum()
# Out:
# Month         0
# Variety       0
# City          0
# Package       0
# Low Price     0
# High Price    0
# Price         0
# dtype: int64

# %%
X, y = new_pumpkins[['Package']].values, new_pumpkins['Price'].values

# %%
X.shape
# Out:
# (415, 1)

# %%
y.shape
# Out:
# (415,)

# %%
from sklearn import model_selection
from sklearn import linear_model

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.2, random_state=0)
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
from sklearn import metrics

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, pred)
plt.show()

# %%
model.predict([[2.75]])
# Out:
# array([33.15655975])

# %%
plt.scatter(X, y)
plt.show()

# %%
metrics.r2_score(y_train, model.predict(X_train))
# Out:
# 0.3315342327998989

# %% [markdown]
# ### Polynomial linear regression

# %%
new_columns = ['Variety', 'Package', 'City', 'Month', 'Price']
poly_pumpkins = new_pumpkins[new_columns]

# %%
poly_pumpkins.head()
# Out:
#     Variety  Package  City  Month      Price
# 70        3        0     1      1  13.636364
# 71        3        0     1      1  16.363636
# 72        3        0     1      2  16.363636
# 73        3        0     1      2  15.454545
# 74        3        0     1      2  13.636364

# %%
corr = poly_pumpkins.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_6d41f_row0_col0, #T_6d41f_row1_col1, #T_6d41f_row2_col2, #T_6d41f_row3_col3, #T_6d41f_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6d41f_row0_col1, #T_6d41f_row0_col2, #T_6d41f_row0_col4, #T_6d41f_row2_col3, #T_6d41f_row4_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6d41f_row0_col3 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_6d41f_row1_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_6d41f_row1_col2 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_6d41f_row1_col3 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_6d41f_row1_col4 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_6d41f_row2_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_6d41f_row2_col1 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_6d41f_row2_col4 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_6d41f_row3_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_6d41f_row3_col1 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_6d41f_row3_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_6d41f_row3_col4 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_6d41f_row4_col1 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_6d41f_row4_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_6d41f_row4_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6d41f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Variety</th>
#       <th class="col_heading level0 col1" >Package</th>
#       <th class="col_heading level0 col2" >City</th>
#       <th class="col_heading level0 col3" >Month</th>
#       <th class="col_heading level0 col4" >Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d41f_level0_row0" class="row_heading level0 row0" >Variety</th>
#       <td id="T_6d41f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_6d41f_row0_col1" class="data row0 col1" >-0.614855</td>
#       <td id="T_6d41f_row0_col2" class="data row0 col2" >-0.248441</td>
#       <td id="T_6d41f_row0_col3" class="data row0 col3" >0.171330</td>
#       <td id="T_6d41f_row0_col4" class="data row0 col4" >-0.863479</td>
#     </tr>
#     <tr>
#       <th id="T_6d41f_level0_row1" class="row_heading level0 row1" >Package</th>
#       <td id="T_6d41f_row1_col0" class="data row1 col0" >-0.614855</td>
#       <td id="T_6d41f_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_6d41f_row1_col2" class="data row1 col2" >0.301604</td>
#       <td id="T_6d41f_row1_col3" class="data row1 col3" >-0.144847</td>
#       <td id="T_6d41f_row1_col4" class="data row1 col4" >0.606171</td>
#     </tr>
#     <tr>
#       <th id="T_6d41f_level0_row2" class="row_heading level0 row2" >City</th>
#       <td id="T_6d41f_row2_col0" class="data row2 col0" >-0.248441</td>
#       <td id="T_6d41f_row2_col1" class="data row2 col1" >0.301604</td>
#       <td id="T_6d41f_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_6d41f_row2_col3" class="data row2 col3" >-0.188728</td>
#       <td id="T_6d41f_row2_col4" class="data row2 col4" >0.323640</td>
#     </tr>
#     <tr>
#       <th id="T_6d41f_level0_row3" class="row_heading level0 row3" >Month</th>
#       <td id="T_6d41f_row3_col0" class="data row3 col0" >0.171330</td>
#       <td id="T_6d41f_row3_col1" class="data row3 col1" >-0.144847</td>
#       <td id="T_6d41f_row3_col2" class="data row3 col2" >-0.188728</td>
#       <td id="T_6d41f_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_6d41f_row3_col4" class="data row3 col4" >-0.148783</td>
#     </tr>
#     <tr>
#       <th id="T_6d41f_level0_row4" class="row_heading level0 row4" >Price</th>
#       <td id="T_6d41f_row4_col0" class="data row4 col0" >-0.863479</td>
#       <td id="T_6d41f_row4_col1" class="data row4 col1" >0.606171</td>
#       <td id="T_6d41f_row4_col2" class="data row4 col2" >0.323640</td>
#       <td id="T_6d41f_row4_col3" class="data row4 col3" >-0.148783</td>
#       <td id="T_6d41f_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
poly_pumpkins
# Out:
#       Variety  Package  City  Month      Price
# 70          3        0     1      1  13.636364
# 71          3        0     1      1  16.363636
# 72          3        0     1      2  16.363636
# 73          3        0     1      2  15.454545
# 74          3        0     1      2  13.636364
# ...       ...      ...   ...    ...        ...
# 1738        1        2     9      1  30.000000
# 1739        1        2     9      1  28.750000
# 1740        1        2     9      1  25.750000
# 1741        1        2     9      1  24.000000
# 1742        1        2     9      1  24.000000
#
# [415 rows x 5 columns]

# %%
X, y = poly_pumpkins[['Package']].values, poly_pumpkins['Price'].values

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

pipeline = make_pipeline(PolynomialFeatures(4), linear_model.LinearRegression())

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.2, random_state=0)

pipeline.fit(X_train, y_train)

y_pred=pipeline.predict(X_test)


y_pred = [t for _, t in sorted(zip(X_test, y_pred))]
X_test = sorted(X_test)

plt.plot(X_test, y_pred)
plt.xlabel('Package')
plt.ylabel('Price')

plt.scatter(X,y)

plt.show()

# %%
pipeline.predict([[2.75]])
# Out:
# array([46.34509342])
